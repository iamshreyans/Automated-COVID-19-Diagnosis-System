# %% [markdown]
# ### **Use this Notebook on Google Colab Free GPU**
# Go to Google Drive, upload this notebook and dataset folders. Rigth click notebook, choose **Open with -> Google Colab**
# <br>
# To activate GPU in Colab, go to **Runtime -> Change Runtime Type**. Under **Hardware accelerator** choose **GPU**

# %% [markdown]
# ### Connect to Google Drive to access Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/COVID Detection'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/COVID Detection

# %% [markdown]
# ### Import all dependencies

# %%
from __future__ import print_function, division
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import cv2
from glob import glob

# %% [markdown]
# ### Define Few Parameters

# %%
#define size to which images are to be resized
IMAGE_SIZE = [100, 100] # feel free to change depending on dataset

# training config:
epochs = 500
batch_size = 32

#define paths
covid_path = 'data/chest/Chest_COVID'
noncovid_path = 'data/chest/Chest_NonCOVID'

# Use glob to grab images from path .jpg or jpeg
covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %% [markdown]
# ### Fetch Images and Class Labels from Files (This might take a while)

# %%
# Preparing Labels
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

import cv2 

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(100,100))
  covid_images.append(image)
  covid_labels.append('Chest_COVID')
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(100,100))
  noncovid_images.append(image)
  noncovid_labels.append('Chest_NonCOVID')

# %% [markdown]
# ### Visualize First 40 Images from Data set

# %%
# look at a random image for fun
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(covid_images, 'Positive COVID-19 Chest X-ray')
plot_images(noncovid_images, 'Negative COVID-19 Chest X-ray')

# %% [markdown]
# ### **Normalization**
# #### Model takes images in the form of array of pixels. Hence convert into array and *normalize*

# %%
# normalize to interval of [0,1]
covid_images = np.array(covid_images) / 255
noncovid_images = np.array(noncovid_images) / 255

# %% [markdown]
# ### **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# split into training and testing
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)


X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %% [markdown]
# ### Visualize a few images from Training and Test sets

# %%
plot_images(covid_x_train, 'X_train')
plot_images(covid_x_test, 'X_test')
# y_train and y_test contain class lables 0 and 1 representing COVID and NonCOVID for X_train and X_test

# %% [markdown]
# ### **Building and Visualizing model**

# %%
DenseNet201 = DenseNet201(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(100, 100, 3)))

outputs = DenseNet201.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=DenseNet201.input, outputs=outputs)

for layer in DenseNet201.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 106, 106, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 50, 50, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 50, 50, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 50, 50, 64)   0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 52, 52, 64)   0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 25, 25, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 25, 25, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 25, 25, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 25, 25, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 25, 25, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 25, 25, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 25, 25, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 25, 25, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 25, 25, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 25, 25, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 25, 25, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 25, 25, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 25, 25, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 25, 25, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 25, 25, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 25, 25, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 25, 25, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 25, 25, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 25, 25, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 25, 25, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 25, 25, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 25, 25, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 25, 25, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 25, 25, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 25, 25, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 25, 25, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 25, 25, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 25, 25, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 25, 25, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 25, 25, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 25, 25, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 25, 25, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 25, 25, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 25, 25, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 25, 25, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 25, 25, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 25, 25, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 25, 25, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 25, 25, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 25, 25, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 25, 25, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 25, 25, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 25, 25, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 25, 25, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 25, 25, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 25, 25, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 12, 12, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 12, 12, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 12, 12, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 12, 12, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 12, 12, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 12, 12, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 12, 12, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 12, 12, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 12, 12, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 12, 12, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 12, 12, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 12, 12, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 12, 12, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 12, 12, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 12, 12, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 12, 12, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 12, 12, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 12, 12, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 12, 12, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 12, 12, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 12, 12, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 12, 12, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 12, 12, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 12, 12, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 12, 12, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 12, 12, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 12, 12, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 12, 12, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 12, 12, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 12, 12, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 12, 12, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 12, 12, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 12, 12, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 12, 12, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 12, 12, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 12, 12, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 12, 12, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 12, 12, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 12, 12, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 12, 12, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 12, 12, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 12, 12, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 12, 12, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 12, 12, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 12, 12, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 12, 12, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 12, 12, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 12, 12, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 12, 12, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 12, 12, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 12, 12, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 12, 12, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 12, 12, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 12, 12, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 12, 12, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 12, 12, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 12, 12, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 12, 12, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 12, 12, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 12, 12, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 12, 12, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 12, 12, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 12, 12, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 12, 12, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 12, 12, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 12, 12, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 12, 12, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 12, 12, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 12, 12, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 12, 12, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 12, 12, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 12, 12, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 12, 12, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 12, 12, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 12, 12, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 12, 12, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 12, 12, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 12, 12, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 12, 12, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 12, 12, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 12, 12, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 12, 12, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 12, 12, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 12, 12, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 12, 12, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 12, 12, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 12, 12, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 12, 12, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 6, 6, 256)    0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 6, 6, 256)    1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 6, 6, 256)    0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 6, 6, 128)    32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 6, 6, 128)    512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 6, 6, 128)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 6, 6, 32)     36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 6, 6, 288)    0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 6, 6, 288)    1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 6, 6, 288)    0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 6, 6, 128)    36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 6, 6, 128)    512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 6, 6, 128)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 6, 6, 32)     36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 6, 6, 320)    0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 6, 6, 320)    1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 6, 6, 320)    0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 6, 6, 128)    40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 6, 6, 128)    512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 6, 6, 128)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 6, 6, 32)     36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 6, 6, 352)    0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 6, 6, 352)    1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 6, 6, 352)    0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 6, 6, 128)    45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 6, 6, 128)    512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 6, 6, 128)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 6, 6, 32)     36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 6, 6, 384)    0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 6, 6, 384)    1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 6, 6, 384)    0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 6, 6, 128)    49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 6, 6, 128)    512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 6, 6, 128)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 6, 6, 32)     36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 6, 6, 416)    0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 6, 6, 416)    1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 6, 6, 416)    0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 6, 6, 128)    53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 6, 6, 128)    512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 6, 6, 128)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 6, 6, 32)     36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 6, 6, 448)    0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 6, 6, 448)    1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 6, 6, 448)    0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 6, 6, 128)    57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 6, 6, 128)    512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 6, 6, 128)    0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 6, 6, 32)     36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 6, 6, 480)    0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 6, 6, 480)    1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 6, 6, 480)    0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 6, 6, 128)    61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 6, 6, 128)    512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 6, 6, 128)    0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 6, 6, 32)     36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 6, 6, 512)    0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 6, 6, 512)    2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 6, 6, 512)    0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 6, 6, 128)    65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 6, 6, 128)    512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 6, 6, 128)    0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 6, 6, 32)     36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 6, 6, 544)    0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 6, 6, 544)    2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 6, 6, 544)    0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 6, 6, 128)    69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 6, 6, 128)    512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 6, 6, 128)    0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 6, 6, 32)     36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 6, 6, 576)    0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 6, 6, 576)    2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 6, 6, 576)    0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 6, 6, 128)    73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 6, 6, 128)    512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 6, 6, 128)    0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 6, 6, 32)     36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 6, 6, 608)    0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 6, 6, 608)    2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 6, 6, 608)    0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 6, 6, 128)    77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 6, 6, 128)    512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 6, 6, 128)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 6, 6, 32)     36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 6, 6, 640)    0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 6, 6, 640)    2560        conv4_block12_concat[0][0]
# ...
# __________________________________________________________________________________________________
# conv5_block23_0_relu (Activatio (None, 3, 3, 1600)   0           conv5_block23_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_conv (Conv2D)   (None, 3, 3, 128)    204800      conv5_block23_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_bn (BatchNormal (None, 3, 3, 128)    512         conv5_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_relu (Activatio (None, 3, 3, 128)    0           conv5_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_2_conv (Conv2D)   (None, 3, 3, 32)     36864       conv5_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_concat (Concatena (None, 3, 3, 1632)   0           conv5_block22_concat[0][0]
#                                                                  conv5_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_bn (BatchNormal (None, 3, 3, 1632)   6528        conv5_block23_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_relu (Activatio (None, 3, 3, 1632)   0           conv5_block24_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_conv (Conv2D)   (None, 3, 3, 128)    208896      conv5_block24_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_bn (BatchNormal (None, 3, 3, 128)    512         conv5_block24_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_relu (Activatio (None, 3, 3, 128)    0           conv5_block24_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_2_conv (Conv2D)   (None, 3, 3, 32)     36864       conv5_block24_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_concat (Concatena (None, 3, 3, 1664)   0           conv5_block23_concat[0][0]
#                                                                  conv5_block24_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_bn (BatchNormal (None, 3, 3, 1664)   6656        conv5_block24_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_relu (Activatio (None, 3, 3, 1664)   0           conv5_block25_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_conv (Conv2D)   (None, 3, 3, 128)    212992      conv5_block25_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_bn (BatchNormal (None, 3, 3, 128)    512         conv5_block25_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_relu (Activatio (None, 3, 3, 128)    0           conv5_block25_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_2_conv (Conv2D)   (None, 3, 3, 32)     36864       conv5_block25_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_concat (Concatena (None, 3, 3, 1696)   0           conv5_block24_concat[0][0]
#                                                                  conv5_block25_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_bn (BatchNormal (None, 3, 3, 1696)   6784        conv5_block25_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_relu (Activatio (None, 3, 3, 1696)   0           conv5_block26_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_conv (Conv2D)   (None, 3, 3, 128)    217088      conv5_block26_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_bn (BatchNormal (None, 3, 3, 128)    512         conv5_block26_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_relu (Activatio (None, 3, 3, 128)    0           conv5_block26_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_2_conv (Conv2D)   (None, 3, 3, 32)     36864       conv5_block26_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_concat (Concatena (None, 3, 3, 1728)   0           conv5_block25_concat[0][0]
#                                                                  conv5_block26_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_bn (BatchNormal (None, 3, 3, 1728)   6912        conv5_block26_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_relu (Activatio (None, 3, 3, 1728)   0           conv5_block27_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_conv (Conv2D)   (None, 3, 3, 128)    221184      conv5_block27_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_bn (BatchNormal (None, 3, 3, 128)    512         conv5_block27_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_relu (Activatio (None, 3, 3, 128)    0           conv5_block27_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_2_conv (Conv2D)   (None, 3, 3, 32)     36864       conv5_block27_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_concat (Concatena (None, 3, 3, 1760)   0           conv5_block26_concat[0][0]
#                                                                  conv5_block27_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_bn (BatchNormal (None, 3, 3, 1760)   7040        conv5_block27_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_relu (Activatio (None, 3, 3, 1760)   0           conv5_block28_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_conv (Conv2D)   (None, 3, 3, 128)    225280      conv5_block28_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_bn (BatchNormal (None, 3, 3, 128)    512         conv5_block28_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 3, 3, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 3, 3, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 3, 3, 1792)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 3, 3, 1792)   7168        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 3, 3, 1792)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 3, 3, 128)    229376      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 3, 3, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 3, 3, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 3, 3, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 3, 3, 1824)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 3, 3, 1824)   7296        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 3, 3, 1824)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 3, 3, 128)    233472      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 3, 3, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 3, 3, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 3, 3, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 3, 3, 1856)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 3, 3, 1856)   7424        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 3, 3, 1856)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 3, 3, 128)    237568      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 3, 3, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 3, 3, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 3, 3, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 3, 3, 1888)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 3, 3, 1888)   7552        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 3, 3, 1888)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 3, 3, 128)    241664      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 3, 3, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 3, 3, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 3, 3, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 3, 3, 1920)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 3, 3, 1920)   7680        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 3, 3, 1920)   0           bn[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 17280)        0           relu[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 17280)        0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            34562       dropout[0][0]
# ==================================================================================================
# Total params: 18,356,546
# Trainable params: 34,562
# Non-trainable params: 18,321,984
# __________________________________________________________________________________________________

# %% [markdown]
# ### **Image Augmentation**
# To train on images at different positions, angles, flips, etc

# %%
train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# %% [markdown]
# ### **Training the model**

# %%
history = model.fit(train_aug.flow(X_train, y_train, batch_size=32),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / 32,
                    steps_per_epoch=len(X_train) / 32,
                    epochs=500)
# Out:
# Epoch 1/500
# 205/205 [==============================] - 44s 121ms/step - loss: 0.8932 - accuracy: 0.7689 - val_loss: 0.8246 - val_accuracy: 0.8149
# Epoch 2/500
# 205/205 [==============================] - 19s 93ms/step - loss: 0.8286 - accuracy: 0.7971 - val_loss: 0.5541 - val_accuracy: 0.8557
# Epoch 3/500
# 205/205 [==============================] - 20s 96ms/step - loss: 0.8366 - accuracy: 0.8080 - val_loss: 0.5438 - val_accuracy: 0.8611
# Epoch 4/500
# 205/205 [==============================] - 19s 94ms/step - loss: 0.8115 - accuracy: 0.8132 - val_loss: 0.5101 - val_accuracy: 0.8587
# Epoch 5/500
# 205/205 [==============================] - 19s 94ms/step - loss: 0.9303 - accuracy: 0.8074 - val_loss: 0.5384 - val_accuracy: 0.8618
# Epoch 6/500
# 205/205 [==============================] - 20s 96ms/step - loss: 0.9873 - accuracy: 0.7991 - val_loss: 0.6256 - val_accuracy: 0.8624
# Epoch 7/500
# 205/205 [==============================] - 19s 93ms/step - loss: 1.1442 - accuracy: 0.8068 - val_loss: 0.7214 - val_accuracy: 0.8630
# Epoch 8/500
# 205/205 [==============================] - 20s 96ms/step - loss: 0.9581 - accuracy: 0.8108 - val_loss: 0.4965 - val_accuracy: 0.8733
# Epoch 9/500
# 205/205 [==============================] - 19s 94ms/step - loss: 0.9430 - accuracy: 0.8149 - val_loss: 0.7574 - val_accuracy: 0.8325
# Epoch 10/500
# 205/205 [==============================] - 19s 93ms/step - loss: 1.0517 - accuracy: 0.8103 - val_loss: 0.9456 - val_accuracy: 0.8343
# Epoch 11/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0987 - accuracy: 0.8048 - val_loss: 0.8569 - val_accuracy: 0.8429
# Epoch 12/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0451 - accuracy: 0.8173 - val_loss: 1.0463 - val_accuracy: 0.8191
# Epoch 13/500
# 205/205 [==============================] - 19s 93ms/step - loss: 0.9906 - accuracy: 0.8172 - val_loss: 0.7886 - val_accuracy: 0.8471
# Epoch 14/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0262 - accuracy: 0.8207 - val_loss: 0.4749 - val_accuracy: 0.8849
# Epoch 15/500
# 205/205 [==============================] - 19s 94ms/step - loss: 0.9938 - accuracy: 0.8199 - val_loss: 0.4251 - val_accuracy: 0.8934
# Epoch 16/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0742 - accuracy: 0.8109 - val_loss: 0.5030 - val_accuracy: 0.8886
# Epoch 17/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0515 - accuracy: 0.8170 - val_loss: 1.5750 - val_accuracy: 0.7832
# Epoch 18/500
# 205/205 [==============================] - 19s 93ms/step - loss: 1.0406 - accuracy: 0.8259 - val_loss: 0.7308 - val_accuracy: 0.8453
# Epoch 19/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0390 - accuracy: 0.8215 - val_loss: 0.7953 - val_accuracy: 0.8502
# Epoch 20/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0951 - accuracy: 0.8173 - val_loss: 0.6381 - val_accuracy: 0.8709
# Epoch 21/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0535 - accuracy: 0.8211 - val_loss: 0.5469 - val_accuracy: 0.8806
# Epoch 22/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0486 - accuracy: 0.8271 - val_loss: 0.5876 - val_accuracy: 0.8745
# Epoch 23/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0175 - accuracy: 0.8205 - val_loss: 0.6354 - val_accuracy: 0.8855
# Epoch 24/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0230 - accuracy: 0.8240 - val_loss: 0.6536 - val_accuracy: 0.8685
# Epoch 25/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0688 - accuracy: 0.8173 - val_loss: 0.5352 - val_accuracy: 0.8855
# Epoch 26/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0303 - accuracy: 0.8243 - val_loss: 0.5320 - val_accuracy: 0.8727
# Epoch 27/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.1465 - accuracy: 0.8125 - val_loss: 0.4925 - val_accuracy: 0.8934
# Epoch 28/500
# 205/205 [==============================] - 19s 94ms/step - loss: 0.9706 - accuracy: 0.8272 - val_loss: 0.9301 - val_accuracy: 0.8325
# Epoch 29/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.1058 - accuracy: 0.8173 - val_loss: 0.5166 - val_accuracy: 0.8812
# Epoch 30/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0255 - accuracy: 0.8250 - val_loss: 0.9235 - val_accuracy: 0.8258
# Epoch 31/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0201 - accuracy: 0.8186 - val_loss: 0.5685 - val_accuracy: 0.8843
# Epoch 32/500
# 205/205 [==============================] - 19s 94ms/step - loss: 0.9996 - accuracy: 0.8250 - val_loss: 0.5135 - val_accuracy: 0.8788
# Epoch 33/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0934 - accuracy: 0.8227 - val_loss: 0.5952 - val_accuracy: 0.8764
# Epoch 34/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0660 - accuracy: 0.8208 - val_loss: 0.6166 - val_accuracy: 0.8733
# Epoch 35/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0372 - accuracy: 0.8269 - val_loss: 0.7703 - val_accuracy: 0.8660
# Epoch 36/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1116 - accuracy: 0.8198 - val_loss: 0.6862 - val_accuracy: 0.8745
# Epoch 37/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0704 - accuracy: 0.8257 - val_loss: 0.5102 - val_accuracy: 0.8739
# Epoch 38/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0760 - accuracy: 0.8224 - val_loss: 0.6546 - val_accuracy: 0.8624
# Epoch 39/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0579 - accuracy: 0.8265 - val_loss: 0.6431 - val_accuracy: 0.8599
# Epoch 40/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0042 - accuracy: 0.8306 - val_loss: 0.8468 - val_accuracy: 0.8392
# Epoch 41/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.1637 - accuracy: 0.8179 - val_loss: 0.7964 - val_accuracy: 0.8557
# Epoch 42/500
# 205/205 [==============================] - 19s 93ms/step - loss: 1.0489 - accuracy: 0.8237 - val_loss: 0.4542 - val_accuracy: 0.8928
# Epoch 43/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0951 - accuracy: 0.8230 - val_loss: 0.8193 - val_accuracy: 0.8557
# Epoch 44/500
# 205/205 [==============================] - 19s 93ms/step - loss: 1.0514 - accuracy: 0.8277 - val_loss: 0.4691 - val_accuracy: 0.8904
# Epoch 45/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.1211 - accuracy: 0.8210 - val_loss: 0.8551 - val_accuracy: 0.8514
# Epoch 46/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.1883 - accuracy: 0.8231 - val_loss: 0.5524 - val_accuracy: 0.8873
# Epoch 47/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0129 - accuracy: 0.8271 - val_loss: 0.4777 - val_accuracy: 0.8940
# Epoch 48/500
# 205/205 [==============================] - 20s 97ms/step - loss: 0.9969 - accuracy: 0.8350 - val_loss: 0.7069 - val_accuracy: 0.8502
# Epoch 49/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0630 - accuracy: 0.8205 - val_loss: 0.5838 - val_accuracy: 0.8794
# Epoch 50/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0614 - accuracy: 0.8228 - val_loss: 0.7466 - val_accuracy: 0.8526
# Epoch 51/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0899 - accuracy: 0.8288 - val_loss: 0.5392 - val_accuracy: 0.8812
# Epoch 52/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0258 - accuracy: 0.8272 - val_loss: 1.0778 - val_accuracy: 0.8301
# Epoch 53/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0377 - accuracy: 0.8260 - val_loss: 0.6052 - val_accuracy: 0.8727
# Epoch 54/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0933 - accuracy: 0.8195 - val_loss: 0.7907 - val_accuracy: 0.8593
# Epoch 55/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0684 - accuracy: 0.8250 - val_loss: 0.5286 - val_accuracy: 0.8825
# Epoch 56/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1660 - accuracy: 0.8173 - val_loss: 0.4987 - val_accuracy: 0.8879
# Epoch 57/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0454 - accuracy: 0.8278 - val_loss: 0.5397 - val_accuracy: 0.8886
# Epoch 58/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0404 - accuracy: 0.8288 - val_loss: 0.5285 - val_accuracy: 0.8703
# Epoch 59/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0719 - accuracy: 0.8280 - val_loss: 0.6220 - val_accuracy: 0.8672
# Epoch 60/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0776 - accuracy: 0.8271 - val_loss: 0.5469 - val_accuracy: 0.8727
# Epoch 61/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0405 - accuracy: 0.8271 - val_loss: 0.5067 - val_accuracy: 0.8855
# Epoch 62/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0648 - accuracy: 0.8263 - val_loss: 0.5759 - val_accuracy: 0.8636
# Epoch 63/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.1075 - accuracy: 0.8192 - val_loss: 0.6657 - val_accuracy: 0.8733
# Epoch 64/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0881 - accuracy: 0.8243 - val_loss: 1.0410 - val_accuracy: 0.8380
# Epoch 65/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0443 - accuracy: 0.8239 - val_loss: 0.6102 - val_accuracy: 0.8867
# Epoch 66/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1898 - accuracy: 0.8222 - val_loss: 0.5744 - val_accuracy: 0.8825
# Epoch 67/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.1139 - accuracy: 0.8193 - val_loss: 0.5309 - val_accuracy: 0.8928
# Epoch 68/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1109 - accuracy: 0.8198 - val_loss: 0.4582 - val_accuracy: 0.8898
# Epoch 69/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.1220 - accuracy: 0.8242 - val_loss: 0.5901 - val_accuracy: 0.8831
# Epoch 70/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.1654 - accuracy: 0.8160 - val_loss: 0.5353 - val_accuracy: 0.8904
# Epoch 71/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.1025 - accuracy: 0.8234 - val_loss: 0.5783 - val_accuracy: 0.8886
# Epoch 72/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0614 - accuracy: 0.8260 - val_loss: 0.5754 - val_accuracy: 0.8764
# Epoch 73/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0620 - accuracy: 0.8271 - val_loss: 0.4744 - val_accuracy: 0.8928
# Epoch 74/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0528 - accuracy: 0.8294 - val_loss: 0.6576 - val_accuracy: 0.8788
# Epoch 75/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.1029 - accuracy: 0.8205 - val_loss: 0.5924 - val_accuracy: 0.8788
# Epoch 76/500
# 205/205 [==============================] - 19s 93ms/step - loss: 0.9957 - accuracy: 0.8314 - val_loss: 0.5742 - val_accuracy: 0.8788
# Epoch 77/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0900 - accuracy: 0.8193 - val_loss: 0.5084 - val_accuracy: 0.8861
# Epoch 78/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0983 - accuracy: 0.8265 - val_loss: 0.5013 - val_accuracy: 0.8886
# Epoch 79/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0556 - accuracy: 0.8278 - val_loss: 0.8889 - val_accuracy: 0.8441
# Epoch 80/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.1592 - accuracy: 0.8193 - val_loss: 0.5910 - val_accuracy: 0.8764
# Epoch 81/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.1978 - accuracy: 0.8146 - val_loss: 0.5676 - val_accuracy: 0.8770
# Epoch 82/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0711 - accuracy: 0.8260 - val_loss: 0.4706 - val_accuracy: 0.8928
# Epoch 83/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0652 - accuracy: 0.8303 - val_loss: 0.8485 - val_accuracy: 0.8520
# Epoch 84/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0783 - accuracy: 0.8222 - val_loss: 0.4801 - val_accuracy: 0.8825
# Epoch 85/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.1231 - accuracy: 0.8215 - val_loss: 0.6782 - val_accuracy: 0.8654
# Epoch 86/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0503 - accuracy: 0.8301 - val_loss: 0.5343 - val_accuracy: 0.8849
# Epoch 87/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0250 - accuracy: 0.8298 - val_loss: 1.5030 - val_accuracy: 0.7856
# Epoch 88/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1327 - accuracy: 0.8192 - val_loss: 0.7184 - val_accuracy: 0.8672
# Epoch 89/500
# 205/205 [==============================] - 19s 93ms/step - loss: 1.1140 - accuracy: 0.8234 - val_loss: 0.5910 - val_accuracy: 0.8703
# Epoch 90/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0530 - accuracy: 0.8310 - val_loss: 0.5287 - val_accuracy: 0.8898
# Epoch 91/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0896 - accuracy: 0.8230 - val_loss: 0.5195 - val_accuracy: 0.8806
# Epoch 92/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.2026 - accuracy: 0.8233 - val_loss: 0.5417 - val_accuracy: 0.8800
# Epoch 93/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0510 - accuracy: 0.8257 - val_loss: 0.5251 - val_accuracy: 0.8904
# Epoch 94/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.1371 - accuracy: 0.8242 - val_loss: 0.8365 - val_accuracy: 0.8502
# Epoch 95/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0316 - accuracy: 0.8286 - val_loss: 0.6503 - val_accuracy: 0.8538
# Epoch 96/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0812 - accuracy: 0.8265 - val_loss: 1.1577 - val_accuracy: 0.8167
# Epoch 97/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0626 - accuracy: 0.8265 - val_loss: 0.4958 - val_accuracy: 0.8806
# Epoch 98/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0330 - accuracy: 0.8263 - val_loss: 1.2681 - val_accuracy: 0.8155
# Epoch 99/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.1374 - accuracy: 0.8157 - val_loss: 0.6136 - val_accuracy: 0.8733
# Epoch 100/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0551 - accuracy: 0.8233 - val_loss: 0.5586 - val_accuracy: 0.8745
# Epoch 101/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0453 - accuracy: 0.8278 - val_loss: 0.5278 - val_accuracy: 0.8910
# Epoch 102/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0443 - accuracy: 0.8256 - val_loss: 0.4216 - val_accuracy: 0.8983
# Epoch 103/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0751 - accuracy: 0.8309 - val_loss: 0.5054 - val_accuracy: 0.8867
# Epoch 104/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0193 - accuracy: 0.8321 - val_loss: 0.5181 - val_accuracy: 0.8861
# Epoch 105/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0442 - accuracy: 0.8265 - val_loss: 0.6793 - val_accuracy: 0.8654
# Epoch 106/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0135 - accuracy: 0.8210 - val_loss: 0.5734 - val_accuracy: 0.8764
# Epoch 107/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.1213 - accuracy: 0.8198 - val_loss: 1.3841 - val_accuracy: 0.8143
# Epoch 108/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1157 - accuracy: 0.8237 - val_loss: 0.7957 - val_accuracy: 0.8386
# Epoch 109/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.1747 - accuracy: 0.8181 - val_loss: 0.4860 - val_accuracy: 0.8879
# Epoch 110/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0557 - accuracy: 0.8283 - val_loss: 0.4621 - val_accuracy: 0.8977
# Epoch 111/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.2300 - accuracy: 0.8091 - val_loss: 0.5288 - val_accuracy: 0.8849
# Epoch 112/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0015 - accuracy: 0.8303 - val_loss: 0.9507 - val_accuracy: 0.8392
# Epoch 113/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.1445 - accuracy: 0.8234 - val_loss: 0.5813 - val_accuracy: 0.8892
# Epoch 114/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0402 - accuracy: 0.8324 - val_loss: 0.8128 - val_accuracy: 0.8532
# Epoch 115/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0109 - accuracy: 0.8277 - val_loss: 0.7616 - val_accuracy: 0.8672
# Epoch 116/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0050 - accuracy: 0.8286 - val_loss: 0.6021 - val_accuracy: 0.8806
# Epoch 117/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.1007 - accuracy: 0.8221 - val_loss: 0.6843 - val_accuracy: 0.8697
# Epoch 118/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.1460 - accuracy: 0.8202 - val_loss: 0.5823 - val_accuracy: 0.8800
# Epoch 119/500
# 205/205 [==============================] - 20s 96ms/step - loss: 0.9995 - accuracy: 0.8330 - val_loss: 0.7566 - val_accuracy: 0.8672
# Epoch 120/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.1508 - accuracy: 0.8265 - val_loss: 0.5387 - val_accuracy: 0.8946
# Epoch 121/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1464 - accuracy: 0.8227 - val_loss: 0.9153 - val_accuracy: 0.8441
# Epoch 122/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.1506 - accuracy: 0.8239 - val_loss: 0.6729 - val_accuracy: 0.8648
# Epoch 123/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.1134 - accuracy: 0.8207 - val_loss: 0.7682 - val_accuracy: 0.8642
# Epoch 124/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0369 - accuracy: 0.8320 - val_loss: 0.5672 - val_accuracy: 0.8831
# Epoch 125/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1157 - accuracy: 0.8291 - val_loss: 0.7895 - val_accuracy: 0.8557
# Epoch 126/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.1093 - accuracy: 0.8213 - val_loss: 0.8678 - val_accuracy: 0.8502
# Epoch 127/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1002 - accuracy: 0.8236 - val_loss: 0.8186 - val_accuracy: 0.8599
# Epoch 128/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.1696 - accuracy: 0.8222 - val_loss: 0.5195 - val_accuracy: 0.8831
# Epoch 129/500
# 205/205 [==============================] - 20s 97ms/step - loss: 0.9730 - accuracy: 0.8324 - val_loss: 0.5028 - val_accuracy: 0.8806
# Epoch 130/500
# 205/205 [==============================] - 20s 96ms/step - loss: 0.9374 - accuracy: 0.8367 - val_loss: 1.0489 - val_accuracy: 0.8295
# Epoch 131/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0941 - accuracy: 0.8260 - val_loss: 0.9084 - val_accuracy: 0.8435
# Epoch 132/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0755 - accuracy: 0.8245 - val_loss: 0.8431 - val_accuracy: 0.8490
# Epoch 133/500
# 205/205 [==============================] - 19s 95ms/step - loss: 0.9993 - accuracy: 0.8323 - val_loss: 0.5167 - val_accuracy: 0.8922
# Epoch 134/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0864 - accuracy: 0.8262 - val_loss: 1.1650 - val_accuracy: 0.8276
# Epoch 135/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0541 - accuracy: 0.8248 - val_loss: 0.5030 - val_accuracy: 0.8855
# Epoch 136/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0698 - accuracy: 0.8309 - val_loss: 0.5201 - val_accuracy: 0.8837
# Epoch 137/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0067 - accuracy: 0.8295 - val_loss: 0.8258 - val_accuracy: 0.8435
# Epoch 138/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0980 - accuracy: 0.8225 - val_loss: 0.5279 - val_accuracy: 0.8922
# Epoch 139/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0675 - accuracy: 0.8240 - val_loss: 0.5882 - val_accuracy: 0.8825
# Epoch 140/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0858 - accuracy: 0.8248 - val_loss: 0.6890 - val_accuracy: 0.8794
# Epoch 141/500
# 205/205 [==============================] - 20s 97ms/step - loss: 0.9747 - accuracy: 0.8336 - val_loss: 0.5431 - val_accuracy: 0.8946
# Epoch 142/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0907 - accuracy: 0.8291 - val_loss: 0.8120 - val_accuracy: 0.8624
# Epoch 143/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0922 - accuracy: 0.8246 - val_loss: 1.4493 - val_accuracy: 0.7893
# Epoch 144/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.1894 - accuracy: 0.8236 - val_loss: 0.5870 - val_accuracy: 0.8788
# Epoch 145/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0712 - accuracy: 0.8257 - val_loss: 0.7188 - val_accuracy: 0.8575
# Epoch 146/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0920 - accuracy: 0.8242 - val_loss: 0.6805 - val_accuracy: 0.8733
# Epoch 147/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0012 - accuracy: 0.8310 - val_loss: 0.5882 - val_accuracy: 0.8806
# Epoch 148/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0431 - accuracy: 0.8318 - val_loss: 0.8894 - val_accuracy: 0.8599
# Epoch 149/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0246 - accuracy: 0.8300 - val_loss: 1.9458 - val_accuracy: 0.7497
# Epoch 150/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0318 - accuracy: 0.8324 - val_loss: 0.4619 - val_accuracy: 0.8977
# Epoch 151/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0289 - accuracy: 0.8324 - val_loss: 0.5003 - val_accuracy: 0.8946
# Epoch 152/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0650 - accuracy: 0.8309 - val_loss: 0.5248 - val_accuracy: 0.8825
# Epoch 153/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0699 - accuracy: 0.8285 - val_loss: 1.1959 - val_accuracy: 0.8039
# Epoch 154/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0763 - accuracy: 0.8277 - val_loss: 0.8433 - val_accuracy: 0.8313
# Epoch 155/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0617 - accuracy: 0.8301 - val_loss: 0.6071 - val_accuracy: 0.8770
# Epoch 156/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0878 - accuracy: 0.8282 - val_loss: 0.8597 - val_accuracy: 0.8496
# Epoch 157/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0242 - accuracy: 0.8301 - val_loss: 0.5245 - val_accuracy: 0.8867
# Epoch 158/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0274 - accuracy: 0.8298 - val_loss: 1.1663 - val_accuracy: 0.8331
# Epoch 159/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0680 - accuracy: 0.8317 - val_loss: 0.5287 - val_accuracy: 0.8916
# Epoch 160/500
# 205/205 [==============================] - 20s 97ms/step - loss: 0.9778 - accuracy: 0.8330 - val_loss: 0.5230 - val_accuracy: 0.8800
# Epoch 161/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.1544 - accuracy: 0.8242 - val_loss: 0.6898 - val_accuracy: 0.8678
# Epoch 162/500
# 205/205 [==============================] - 20s 97ms/step - loss: 0.9729 - accuracy: 0.8364 - val_loss: 0.4414 - val_accuracy: 0.8928
# Epoch 163/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0107 - accuracy: 0.8336 - val_loss: 0.4534 - val_accuracy: 0.8989
# Epoch 164/500
# 205/205 [==============================] - 19s 95ms/step - loss: 0.9663 - accuracy: 0.8346 - val_loss: 0.4394 - val_accuracy: 0.8892
# Epoch 165/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0315 - accuracy: 0.8301 - val_loss: 1.1976 - val_accuracy: 0.8362
# Epoch 166/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0320 - accuracy: 0.8312 - val_loss: 0.5416 - val_accuracy: 0.8837
# Epoch 167/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.1273 - accuracy: 0.8256 - val_loss: 0.5283 - val_accuracy: 0.8922
# Epoch 168/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0069 - accuracy: 0.8330 - val_loss: 0.4775 - val_accuracy: 0.8952
# Epoch 169/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0868 - accuracy: 0.8300 - val_loss: 0.5124 - val_accuracy: 0.8898
# Epoch 170/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0607 - accuracy: 0.8208 - val_loss: 0.8817 - val_accuracy: 0.8410
# Epoch 171/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0630 - accuracy: 0.8268 - val_loss: 0.9020 - val_accuracy: 0.8417
# Epoch 172/500
# 205/205 [==============================] - 20s 97ms/step - loss: 0.9703 - accuracy: 0.8321 - val_loss: 0.7541 - val_accuracy: 0.8307
# Epoch 173/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0890 - accuracy: 0.8216 - val_loss: 0.5149 - val_accuracy: 0.8825
# Epoch 174/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0606 - accuracy: 0.8246 - val_loss: 0.5453 - val_accuracy: 0.8861
# Epoch 175/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1017 - accuracy: 0.8219 - val_loss: 0.6111 - val_accuracy: 0.8782
# Epoch 176/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0368 - accuracy: 0.8254 - val_loss: 1.0022 - val_accuracy: 0.8380
# Epoch 177/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0920 - accuracy: 0.8208 - val_loss: 0.7733 - val_accuracy: 0.8685
# Epoch 178/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.1120 - accuracy: 0.8248 - val_loss: 0.9656 - val_accuracy: 0.8380
# Epoch 179/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1208 - accuracy: 0.8283 - val_loss: 0.6205 - val_accuracy: 0.8697
# Epoch 180/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.1154 - accuracy: 0.8286 - val_loss: 0.5369 - val_accuracy: 0.8867
# Epoch 181/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0816 - accuracy: 0.8230 - val_loss: 0.8004 - val_accuracy: 0.8685
# Epoch 182/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0609 - accuracy: 0.8312 - val_loss: 0.7050 - val_accuracy: 0.8697
# Epoch 183/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0395 - accuracy: 0.8341 - val_loss: 0.8109 - val_accuracy: 0.8551
# Epoch 184/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.1356 - accuracy: 0.8211 - val_loss: 0.4984 - val_accuracy: 0.8879
# Epoch 185/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.1208 - accuracy: 0.8274 - val_loss: 1.4010 - val_accuracy: 0.8161
# Epoch 186/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.2137 - accuracy: 0.8199 - val_loss: 0.5324 - val_accuracy: 0.8873
# Epoch 187/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0452 - accuracy: 0.8304 - val_loss: 0.6668 - val_accuracy: 0.8715
# Epoch 188/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0868 - accuracy: 0.8257 - val_loss: 0.5359 - val_accuracy: 0.8879
# Epoch 189/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0351 - accuracy: 0.8335 - val_loss: 0.5656 - val_accuracy: 0.8825
# Epoch 190/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0388 - accuracy: 0.8228 - val_loss: 1.0951 - val_accuracy: 0.8325
# Epoch 191/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0214 - accuracy: 0.8282 - val_loss: 0.7036 - val_accuracy: 0.8691
# Epoch 192/500
# 205/205 [==============================] - 20s 96ms/step - loss: 0.9664 - accuracy: 0.8352 - val_loss: 0.6172 - val_accuracy: 0.8703
# Epoch 193/500
# 205/205 [==============================] - 20s 97ms/step - loss: 0.9472 - accuracy: 0.8333 - val_loss: 0.5564 - val_accuracy: 0.8800
# Epoch 194/500
# 205/205 [==============================] - 20s 97ms/step - loss: 0.9974 - accuracy: 0.8323 - val_loss: 0.9515 - val_accuracy: 0.8429
# Epoch 195/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0294 - accuracy: 0.8341 - val_loss: 0.5464 - val_accuracy: 0.8873
# Epoch 196/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0636 - accuracy: 0.8320 - val_loss: 0.5758 - val_accuracy: 0.8873
# Epoch 197/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0853 - accuracy: 0.8318 - val_loss: 0.5825 - val_accuracy: 0.8831
# Epoch 198/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0537 - accuracy: 0.8266 - val_loss: 0.5083 - val_accuracy: 0.8946
# Epoch 199/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0261 - accuracy: 0.8330 - val_loss: 0.5739 - val_accuracy: 0.8776
# Epoch 200/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0180 - accuracy: 0.8335 - val_loss: 0.5993 - val_accuracy: 0.8849
# Epoch 201/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0164 - accuracy: 0.8309 - val_loss: 0.6138 - val_accuracy: 0.8685
# Epoch 202/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0345 - accuracy: 0.8285 - val_loss: 0.7159 - val_accuracy: 0.8855
# Epoch 203/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0940 - accuracy: 0.8317 - val_loss: 0.8250 - val_accuracy: 0.8538
# Epoch 204/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0894 - accuracy: 0.8254 - val_loss: 0.5638 - val_accuracy: 0.8764
# Epoch 205/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0069 - accuracy: 0.8333 - val_loss: 0.7945 - val_accuracy: 0.8569
# Epoch 206/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0961 - accuracy: 0.8216 - val_loss: 1.5639 - val_accuracy: 0.7820
# Epoch 207/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0455 - accuracy: 0.8350 - val_loss: 0.7892 - val_accuracy: 0.8581
# Epoch 208/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.1820 - accuracy: 0.8298 - val_loss: 0.7604 - val_accuracy: 0.8697
# Epoch 209/500
# 205/205 [==============================] - 20s 97ms/step - loss: 0.9764 - accuracy: 0.8370 - val_loss: 0.4786 - val_accuracy: 0.8922
# Epoch 210/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.2109 - accuracy: 0.8163 - val_loss: 0.4847 - val_accuracy: 0.8946
# Epoch 211/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0114 - accuracy: 0.8303 - val_loss: 0.5814 - val_accuracy: 0.8831
# Epoch 212/500
# 205/205 [==============================] - 20s 97ms/step - loss: 0.9988 - accuracy: 0.8321 - val_loss: 0.6969 - val_accuracy: 0.8544
# Epoch 213/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.0939 - accuracy: 0.8312 - val_loss: 0.6574 - val_accuracy: 0.8685
# Epoch 214/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.1324 - accuracy: 0.8282 - val_loss: 0.9460 - val_accuracy: 0.8532
# Epoch 215/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0791 - accuracy: 0.8338 - val_loss: 0.5997 - val_accuracy: 0.8794
# Epoch 216/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0097 - accuracy: 0.8327 - val_loss: 0.4727 - val_accuracy: 0.8904
# Epoch 217/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0115 - accuracy: 0.8368 - val_loss: 0.7496 - val_accuracy: 0.8660
# Epoch 218/500
# 205/205 [==============================] - 19s 95ms/step - loss: 1.1500 - accuracy: 0.8289 - val_loss: 0.5488 - val_accuracy: 0.8843
# Epoch 219/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0943 - accuracy: 0.8320 - val_loss: 0.5999 - val_accuracy: 0.8916
# Epoch 220/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1095 - accuracy: 0.8301 - val_loss: 0.6487 - val_accuracy: 0.8776
# Epoch 221/500
# 205/205 [==============================] - 19s 95ms/step - loss: 0.9806 - accuracy: 0.8335 - val_loss: 1.1299 - val_accuracy: 0.8356
# Epoch 222/500
# 205/205 [==============================] - 19s 94ms/step - loss: 1.0391 - accuracy: 0.8317 - val_loss: 0.5195 - val_accuracy: 0.8952
# Epoch 223/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.1474 - accuracy: 0.8283 - val_loss: 2.4344 - val_accuracy: 0.7503
# Epoch 224/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0877 - accuracy: 0.8300 - val_loss: 0.5663 - val_accuracy: 0.8764
# Epoch 225/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.1365 - accuracy: 0.8269 - val_loss: 0.4881 - val_accuracy: 0.8989
# Epoch 226/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0713 - accuracy: 0.8342 - val_loss: 0.4693 - val_accuracy: 0.8916
# Epoch 227/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0226 - accuracy: 0.8304 - val_loss: 0.7522 - val_accuracy: 0.8721
# Epoch 228/500
# 205/205 [==============================] - 20s 97ms/step - loss: 0.9841 - accuracy: 0.8327 - val_loss: 0.5958 - val_accuracy: 0.8788
# Epoch 229/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0390 - accuracy: 0.8289 - val_loss: 0.5039 - val_accuracy: 0.8861
# Epoch 230/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0422 - accuracy: 0.8295 - val_loss: 0.5285 - val_accuracy: 0.8898
# Epoch 231/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.1027 - accuracy: 0.8265 - val_loss: 0.7638 - val_accuracy: 0.8727
# Epoch 232/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0121 - accuracy: 0.8314 - val_loss: 1.6341 - val_accuracy: 0.7716
# Epoch 233/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.1202 - accuracy: 0.8294 - val_loss: 0.5146 - val_accuracy: 0.8892
# Epoch 234/500
# 205/205 [==============================] - 20s 96ms/step - loss: 0.9502 - accuracy: 0.8390 - val_loss: 1.0473 - val_accuracy: 0.8331
# Epoch 235/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.2304 - accuracy: 0.8204 - val_loss: 0.5138 - val_accuracy: 0.8977
# Epoch 236/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0304 - accuracy: 0.8336 - val_loss: 0.4450 - val_accuracy: 0.8946
# Epoch 237/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0390 - accuracy: 0.8315 - val_loss: 0.7563 - val_accuracy: 0.8611
# Epoch 238/500
# 205/205 [==============================] - 20s 95ms/step - loss: 1.0636 - accuracy: 0.8297 - val_loss: 0.5189 - val_accuracy: 0.8892
# Epoch 239/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0378 - accuracy: 0.8306 - val_loss: 0.5538 - val_accuracy: 0.8776
# Epoch 240/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0777 - accuracy: 0.8320 - val_loss: 0.7122 - val_accuracy: 0.8709
# Epoch 241/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0711 - accuracy: 0.8248 - val_loss: 0.8898 - val_accuracy: 0.8636
# Epoch 242/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0649 - accuracy: 0.8374 - val_loss: 0.5258 - val_accuracy: 0.8904
# Epoch 243/500
# 205/205 [==============================] - 20s 96ms/step - loss: 1.0478 - accuracy: 0.8332 - val_loss: 0.4919 - val_accuracy: 0.8776
# Epoch 244/500
# 205/205 [==============================] - 20s 100ms/step - loss: 0.9736 - accuracy: 0.8358 - val_loss: 0.5984 - val_accuracy: 0.8849
# Epoch 245/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0044 - accuracy: 0.8349 - val_loss: 0.6213 - val_accuracy: 0.8739
# Epoch 246/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0756 - accuracy: 0.8219 - val_loss: 0.5251 - val_accuracy: 0.8794
# Epoch 247/500
# 205/205 [==============================] - 20s 97ms/step - loss: 1.0555 - accuracy: 0.8274 - val_loss: 0.5043 - val_accuracy: 0.8788
# Epoch 248/500
# 205/205 [==============================] - 20s 98ms/step - loss: 0.9057 - accuracy: 0.8373 - val_loss: 0.4439 - val_accuracy: 0.8886
# Epoch 249/500
# 205/205 [==============================] - 20s 100ms/step - loss: 1.0588 - accuracy: 0.8259 - val_loss: 0.5043 - val_accuracy: 0.8892
# Epoch 250/500
# 205/205 [==============================] - 20s 98ms/step - loss: 0.9804 - accuracy: 0.8432 - val_loss: 0.6194 - val_accuracy: 0.8642
# Epoch 251/500
# 205/205 [==============================] - 20s 98ms/step - loss: 0.9887 - accuracy: 0.8315 - val_loss: 0.4597 - val_accuracy: 0.8940
# Epoch 252/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0324 - accuracy: 0.8368 - val_loss: 0.4987 - val_accuracy: 0.8800
# Epoch 253/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0214 - accuracy: 0.8376 - val_loss: 0.5740 - val_accuracy: 0.8843
# Epoch 254/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0875 - accuracy: 0.8336 - val_loss: 0.5005 - val_accuracy: 0.8940
# Epoch 255/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.1534 - accuracy: 0.8257 - val_loss: 0.7146 - val_accuracy: 0.8691
# Epoch 256/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.1158 - accuracy: 0.8291 - val_loss: 0.9526 - val_accuracy: 0.8423
# Epoch 257/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.1044 - accuracy: 0.8341 - val_loss: 0.5902 - val_accuracy: 0.8721
# Epoch 258/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0604 - accuracy: 0.8243 - val_loss: 0.4791 - val_accuracy: 0.8928
# Epoch 259/500
# 205/205 [==============================] - 21s 100ms/step - loss: 1.0713 - accuracy: 0.8309 - val_loss: 0.4988 - val_accuracy: 0.8843
# Epoch 260/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0793 - accuracy: 0.8310 - val_loss: 0.5066 - val_accuracy: 0.8886
# Epoch 261/500
# 205/205 [==============================] - 21s 100ms/step - loss: 1.0582 - accuracy: 0.8350 - val_loss: 0.9479 - val_accuracy: 0.8459
# Epoch 262/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0424 - accuracy: 0.8352 - val_loss: 1.7256 - val_accuracy: 0.7747
# Epoch 263/500
# 205/205 [==============================] - 21s 100ms/step - loss: 1.0435 - accuracy: 0.8327 - val_loss: 0.7155 - val_accuracy: 0.8611
# Epoch 264/500
# 205/205 [==============================] - 21s 100ms/step - loss: 1.0420 - accuracy: 0.8356 - val_loss: 0.5540 - val_accuracy: 0.8959
# Epoch 265/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0581 - accuracy: 0.8330 - val_loss: 0.5543 - val_accuracy: 0.8837
# Epoch 266/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0486 - accuracy: 0.8282 - val_loss: 0.4811 - val_accuracy: 0.8904
# Epoch 267/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0035 - accuracy: 0.8306 - val_loss: 0.9576 - val_accuracy: 0.8435
# Epoch 268/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0769 - accuracy: 0.8312 - val_loss: 0.4721 - val_accuracy: 0.8977
# Epoch 269/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.1098 - accuracy: 0.8286 - val_loss: 0.6729 - val_accuracy: 0.8715
# Epoch 270/500
# 205/205 [==============================] - 21s 101ms/step - loss: 0.9648 - accuracy: 0.8371 - val_loss: 0.4649 - val_accuracy: 0.8983
# Epoch 271/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0419 - accuracy: 0.8300 - val_loss: 0.6484 - val_accuracy: 0.8770
# Epoch 272/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0399 - accuracy: 0.8310 - val_loss: 1.1369 - val_accuracy: 0.8222
# Epoch 273/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.1010 - accuracy: 0.8297 - val_loss: 0.5798 - val_accuracy: 0.8867
# Epoch 274/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0391 - accuracy: 0.8304 - val_loss: 0.7540 - val_accuracy: 0.8703
# Epoch 275/500
# 205/205 [==============================] - 20s 98ms/step - loss: 0.9890 - accuracy: 0.8350 - val_loss: 0.6023 - val_accuracy: 0.8794
# Epoch 276/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0481 - accuracy: 0.8307 - val_loss: 0.6224 - val_accuracy: 0.8715
# Epoch 277/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.2125 - accuracy: 0.8179 - val_loss: 0.6340 - val_accuracy: 0.8819
# Epoch 278/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0746 - accuracy: 0.8278 - val_loss: 0.8548 - val_accuracy: 0.8544
# Epoch 279/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0573 - accuracy: 0.8269 - val_loss: 0.4799 - val_accuracy: 0.8849
# Epoch 280/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0325 - accuracy: 0.8315 - val_loss: 1.0809 - val_accuracy: 0.8331
# Epoch 281/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.1607 - accuracy: 0.8275 - val_loss: 1.5785 - val_accuracy: 0.8033
# Epoch 282/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.1215 - accuracy: 0.8268 - val_loss: 0.6862 - val_accuracy: 0.8630
# Epoch 283/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0570 - accuracy: 0.8312 - val_loss: 1.1795 - val_accuracy: 0.8057
# Epoch 284/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.2316 - accuracy: 0.8170 - val_loss: 0.9602 - val_accuracy: 0.8307
# Epoch 285/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0807 - accuracy: 0.8283 - val_loss: 0.4866 - val_accuracy: 0.8946
# Epoch 286/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0631 - accuracy: 0.8332 - val_loss: 0.5541 - val_accuracy: 0.8819
# Epoch 287/500
# 205/205 [==============================] - 21s 100ms/step - loss: 1.0723 - accuracy: 0.8265 - val_loss: 0.5301 - val_accuracy: 0.8892
# Epoch 288/500
# 205/205 [==============================] - 20s 99ms/step - loss: 0.9598 - accuracy: 0.8384 - val_loss: 0.5700 - val_accuracy: 0.8794
# Epoch 289/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.1961 - accuracy: 0.8224 - val_loss: 0.7814 - val_accuracy: 0.8508
# Epoch 290/500
# 205/205 [==============================] - 21s 101ms/step - loss: 0.9890 - accuracy: 0.8385 - val_loss: 0.6849 - val_accuracy: 0.8703
# Epoch 291/500
# 205/205 [==============================] - 21s 100ms/step - loss: 0.9651 - accuracy: 0.8417 - val_loss: 1.0387 - val_accuracy: 0.8374
# Epoch 292/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0527 - accuracy: 0.8286 - val_loss: 0.6463 - val_accuracy: 0.8715
# Epoch 293/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0921 - accuracy: 0.8205 - val_loss: 0.6588 - val_accuracy: 0.8782
# Epoch 294/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0181 - accuracy: 0.8368 - val_loss: 0.5713 - val_accuracy: 0.8733
# Epoch 295/500
# 205/205 [==============================] - 21s 100ms/step - loss: 1.0145 - accuracy: 0.8352 - val_loss: 0.7461 - val_accuracy: 0.8648
# Epoch 296/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0168 - accuracy: 0.8338 - val_loss: 0.5156 - val_accuracy: 0.8849
# Epoch 297/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0989 - accuracy: 0.8278 - val_loss: 0.5693 - val_accuracy: 0.8879
# Epoch 298/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0967 - accuracy: 0.8254 - val_loss: 0.5451 - val_accuracy: 0.8837
# Epoch 299/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0906 - accuracy: 0.8342 - val_loss: 0.5117 - val_accuracy: 0.8849
# Epoch 300/500
# 205/205 [==============================] - 21s 100ms/step - loss: 1.0099 - accuracy: 0.8353 - val_loss: 0.6425 - val_accuracy: 0.8715
# Epoch 301/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0342 - accuracy: 0.8320 - val_loss: 0.5440 - val_accuracy: 0.8898
# Epoch 302/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0458 - accuracy: 0.8318 - val_loss: 0.8071 - val_accuracy: 0.8575
# Epoch 303/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0919 - accuracy: 0.8294 - val_loss: 0.4619 - val_accuracy: 0.9007
# Epoch 304/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0444 - accuracy: 0.8295 - val_loss: 0.7717 - val_accuracy: 0.8697
# Epoch 305/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0275 - accuracy: 0.8317 - val_loss: 0.4362 - val_accuracy: 0.8959
# Epoch 306/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.1269 - accuracy: 0.8239 - val_loss: 0.6122 - val_accuracy: 0.8733
# Epoch 307/500
# 205/205 [==============================] - 20s 100ms/step - loss: 1.0941 - accuracy: 0.8269 - val_loss: 0.4671 - val_accuracy: 0.8922
# Epoch 308/500
# 205/205 [==============================] - 20s 100ms/step - loss: 0.9176 - accuracy: 0.8435 - val_loss: 0.6046 - val_accuracy: 0.8879
# Epoch 309/500
# 205/205 [==============================] - 21s 100ms/step - loss: 1.0581 - accuracy: 0.8269 - val_loss: 1.7639 - val_accuracy: 0.7686
# Epoch 310/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0896 - accuracy: 0.8338 - val_loss: 0.4242 - val_accuracy: 0.9007
# Epoch 311/500
# 205/205 [==============================] - 21s 100ms/step - loss: 0.9966 - accuracy: 0.8368 - val_loss: 0.7504 - val_accuracy: 0.8642
# Epoch 312/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0289 - accuracy: 0.8330 - val_loss: 0.4685 - val_accuracy: 0.8892
# Epoch 313/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0075 - accuracy: 0.8356 - val_loss: 0.4663 - val_accuracy: 0.8971
# Epoch 314/500
# 205/205 [==============================] - 20s 99ms/step - loss: 0.9961 - accuracy: 0.8346 - val_loss: 0.6404 - val_accuracy: 0.8867
# Epoch 315/500
# 205/205 [==============================] - 20s 99ms/step - loss: 0.9716 - accuracy: 0.8356 - val_loss: 0.7879 - val_accuracy: 0.8678
# Epoch 316/500
# 205/205 [==============================] - 21s 100ms/step - loss: 1.0647 - accuracy: 0.8250 - val_loss: 0.8080 - val_accuracy: 0.8660
# Epoch 317/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0384 - accuracy: 0.8271 - val_loss: 0.4908 - val_accuracy: 0.9019
# Epoch 318/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.1073 - accuracy: 0.8266 - val_loss: 0.7052 - val_accuracy: 0.8648
# Epoch 319/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.1113 - accuracy: 0.8298 - val_loss: 0.7511 - val_accuracy: 0.8636
# Epoch 320/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0153 - accuracy: 0.8306 - val_loss: 0.4650 - val_accuracy: 0.8898
# Epoch 321/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0317 - accuracy: 0.8320 - val_loss: 0.8328 - val_accuracy: 0.8569
# Epoch 322/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0305 - accuracy: 0.8317 - val_loss: 0.5096 - val_accuracy: 0.8922
# Epoch 323/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0574 - accuracy: 0.8286 - val_loss: 0.5046 - val_accuracy: 0.8861
# Epoch 324/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0471 - accuracy: 0.8338 - val_loss: 0.4835 - val_accuracy: 0.8965
# Epoch 325/500
# 205/205 [==============================] - 20s 100ms/step - loss: 0.9891 - accuracy: 0.8307 - val_loss: 0.5063 - val_accuracy: 0.9013
# Epoch 326/500
# 205/205 [==============================] - 21s 101ms/step - loss: 0.9936 - accuracy: 0.8329 - val_loss: 0.5804 - val_accuracy: 0.8873
# Epoch 327/500
# 205/205 [==============================] - 20s 98ms/step - loss: 1.0026 - accuracy: 0.8277 - val_loss: 1.9912 - val_accuracy: 0.7576
# ...
# Epoch 393/500
# 205/205 [==============================] - 21s 103ms/step - loss: 0.9790 - accuracy: 0.8365 - val_loss: 0.5750 - val_accuracy: 0.8867
# Epoch 394/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0884 - accuracy: 0.8315 - val_loss: 0.6939 - val_accuracy: 0.8752
# Epoch 395/500
# 205/205 [==============================] - 21s 100ms/step - loss: 1.0853 - accuracy: 0.8320 - val_loss: 0.5460 - val_accuracy: 0.8770
# Epoch 396/500
# 205/205 [==============================] - 21s 101ms/step - loss: 0.9954 - accuracy: 0.8347 - val_loss: 1.5662 - val_accuracy: 0.7954
# Epoch 397/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.1449 - accuracy: 0.8272 - val_loss: 0.5230 - val_accuracy: 0.8916
# Epoch 398/500
# 205/205 [==============================] - 21s 101ms/step - loss: 0.9473 - accuracy: 0.8411 - val_loss: 0.5895 - val_accuracy: 0.8782
# Epoch 399/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0103 - accuracy: 0.8358 - val_loss: 2.2054 - val_accuracy: 0.7594
# Epoch 400/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0154 - accuracy: 0.8353 - val_loss: 0.7053 - val_accuracy: 0.8691
# Epoch 401/500
# 205/205 [==============================] - 21s 103ms/step - loss: 0.9212 - accuracy: 0.8405 - val_loss: 0.4703 - val_accuracy: 0.8946
# Epoch 402/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0082 - accuracy: 0.8285 - val_loss: 1.1683 - val_accuracy: 0.8283
# Epoch 403/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0267 - accuracy: 0.8344 - val_loss: 0.6038 - val_accuracy: 0.8709
# Epoch 404/500
# 205/205 [==============================] - 21s 103ms/step - loss: 0.9849 - accuracy: 0.8422 - val_loss: 0.9836 - val_accuracy: 0.8398
# Epoch 405/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0635 - accuracy: 0.8324 - val_loss: 0.5951 - val_accuracy: 0.8709
# Epoch 406/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0435 - accuracy: 0.8278 - val_loss: 0.5416 - val_accuracy: 0.8940
# Epoch 407/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0498 - accuracy: 0.8266 - val_loss: 0.9808 - val_accuracy: 0.8484
# Epoch 408/500
# 205/205 [==============================] - 21s 100ms/step - loss: 1.0717 - accuracy: 0.8300 - val_loss: 0.5016 - val_accuracy: 0.8959
# Epoch 409/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0695 - accuracy: 0.8326 - val_loss: 0.4925 - val_accuracy: 0.8886
# Epoch 410/500
# 205/205 [==============================] - 21s 100ms/step - loss: 1.0477 - accuracy: 0.8283 - val_loss: 0.7372 - val_accuracy: 0.8642
# Epoch 411/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0897 - accuracy: 0.8336 - val_loss: 0.5122 - val_accuracy: 0.8946
# Epoch 412/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0016 - accuracy: 0.8355 - val_loss: 1.1478 - val_accuracy: 0.8136
# Epoch 413/500
# 205/205 [==============================] - 21s 103ms/step - loss: 0.9665 - accuracy: 0.8405 - val_loss: 0.5565 - val_accuracy: 0.8867
# Epoch 414/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0423 - accuracy: 0.8344 - val_loss: 0.5454 - val_accuracy: 0.8886
# Epoch 415/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.1048 - accuracy: 0.8280 - val_loss: 0.5291 - val_accuracy: 0.8934
# Epoch 416/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0461 - accuracy: 0.8333 - val_loss: 1.1183 - val_accuracy: 0.8319
# Epoch 417/500
# 205/205 [==============================] - 21s 103ms/step - loss: 0.9706 - accuracy: 0.8358 - val_loss: 0.6336 - val_accuracy: 0.8794
# Epoch 418/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0317 - accuracy: 0.8256 - val_loss: 0.6719 - val_accuracy: 0.8806
# Epoch 419/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0564 - accuracy: 0.8318 - val_loss: 0.5170 - val_accuracy: 0.8934
# Epoch 420/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0693 - accuracy: 0.8275 - val_loss: 1.0750 - val_accuracy: 0.8295
# Epoch 421/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.1059 - accuracy: 0.8297 - val_loss: 0.4615 - val_accuracy: 0.8983
# Epoch 422/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0209 - accuracy: 0.8419 - val_loss: 0.8536 - val_accuracy: 0.8648
# Epoch 423/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0154 - accuracy: 0.8388 - val_loss: 0.5073 - val_accuracy: 0.8855
# Epoch 424/500
# 205/205 [==============================] - 21s 103ms/step - loss: 0.9570 - accuracy: 0.8410 - val_loss: 0.5552 - val_accuracy: 0.8825
# Epoch 425/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0226 - accuracy: 0.8359 - val_loss: 0.4673 - val_accuracy: 0.8995
# Epoch 426/500
# 205/205 [==============================] - 21s 103ms/step - loss: 0.9743 - accuracy: 0.8353 - val_loss: 0.8208 - val_accuracy: 0.8672
# Epoch 427/500
# 205/205 [==============================] - 21s 100ms/step - loss: 0.9833 - accuracy: 0.8374 - val_loss: 0.5933 - val_accuracy: 0.8831
# Epoch 428/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0310 - accuracy: 0.8324 - val_loss: 0.4445 - val_accuracy: 0.9007
# Epoch 429/500
# 205/205 [==============================] - 20s 100ms/step - loss: 1.0340 - accuracy: 0.8332 - val_loss: 0.5835 - val_accuracy: 0.8825
# Epoch 430/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0778 - accuracy: 0.8339 - val_loss: 0.6200 - val_accuracy: 0.8678
# Epoch 431/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0351 - accuracy: 0.8338 - val_loss: 0.7882 - val_accuracy: 0.8630
# Epoch 432/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0373 - accuracy: 0.8344 - val_loss: 0.6049 - val_accuracy: 0.8764
# Epoch 433/500
# 205/205 [==============================] - 20s 99ms/step - loss: 1.0321 - accuracy: 0.8344 - val_loss: 0.8401 - val_accuracy: 0.8666
# Epoch 434/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0374 - accuracy: 0.8327 - val_loss: 0.5290 - val_accuracy: 0.8861
# Epoch 435/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.1285 - accuracy: 0.8282 - val_loss: 0.6916 - val_accuracy: 0.8794
# Epoch 436/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0432 - accuracy: 0.8329 - val_loss: 1.7883 - val_accuracy: 0.7850
# Epoch 437/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.1416 - accuracy: 0.8257 - val_loss: 0.5389 - val_accuracy: 0.8855
# Epoch 438/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0696 - accuracy: 0.8350 - val_loss: 0.6558 - val_accuracy: 0.8764
# Epoch 439/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.1574 - accuracy: 0.8289 - val_loss: 0.5881 - val_accuracy: 0.8837
# Epoch 440/500
# 205/205 [==============================] - 21s 101ms/step - loss: 0.9961 - accuracy: 0.8385 - val_loss: 0.4909 - val_accuracy: 0.8770
# Epoch 441/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.2134 - accuracy: 0.8224 - val_loss: 1.4224 - val_accuracy: 0.7954
# Epoch 442/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0138 - accuracy: 0.8405 - val_loss: 0.6617 - val_accuracy: 0.8745
# Epoch 443/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0603 - accuracy: 0.8301 - val_loss: 0.9226 - val_accuracy: 0.8520
# Epoch 444/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0411 - accuracy: 0.8332 - val_loss: 0.6331 - val_accuracy: 0.8837
# Epoch 445/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.1561 - accuracy: 0.8265 - val_loss: 0.6120 - val_accuracy: 0.8745
# Epoch 446/500
# 205/205 [==============================] - 21s 103ms/step - loss: 0.9993 - accuracy: 0.8335 - val_loss: 0.4828 - val_accuracy: 0.9007
# Epoch 447/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.1006 - accuracy: 0.8243 - val_loss: 0.5917 - val_accuracy: 0.8904
# Epoch 448/500
# 205/205 [==============================] - 21s 104ms/step - loss: 0.9983 - accuracy: 0.8335 - val_loss: 0.5358 - val_accuracy: 0.8806
# Epoch 449/500
# 205/205 [==============================] - 21s 104ms/step - loss: 0.9812 - accuracy: 0.8367 - val_loss: 0.8927 - val_accuracy: 0.8484
# Epoch 450/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.0235 - accuracy: 0.8298 - val_loss: 1.1482 - val_accuracy: 0.8362
# Epoch 451/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.0771 - accuracy: 0.8275 - val_loss: 0.4662 - val_accuracy: 0.8928
# Epoch 452/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0747 - accuracy: 0.8294 - val_loss: 0.5162 - val_accuracy: 0.8910
# Epoch 453/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.1766 - accuracy: 0.8251 - val_loss: 1.3225 - val_accuracy: 0.8258
# Epoch 454/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.0478 - accuracy: 0.8364 - val_loss: 0.5075 - val_accuracy: 0.8952
# Epoch 455/500
# 205/205 [==============================] - 21s 104ms/step - loss: 0.9974 - accuracy: 0.8391 - val_loss: 0.6053 - val_accuracy: 0.8910
# Epoch 456/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0654 - accuracy: 0.8339 - val_loss: 0.6001 - val_accuracy: 0.8916
# Epoch 457/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0348 - accuracy: 0.8333 - val_loss: 0.5572 - val_accuracy: 0.8873
# Epoch 458/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.1112 - accuracy: 0.8376 - val_loss: 0.5829 - val_accuracy: 0.8910
# Epoch 459/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.0055 - accuracy: 0.8358 - val_loss: 0.4753 - val_accuracy: 0.8995
# Epoch 460/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0636 - accuracy: 0.8324 - val_loss: 1.2205 - val_accuracy: 0.8210
# Epoch 461/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0582 - accuracy: 0.8326 - val_loss: 1.5891 - val_accuracy: 0.7783
# Epoch 462/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0960 - accuracy: 0.8288 - val_loss: 0.5235 - val_accuracy: 0.8989
# Epoch 463/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0840 - accuracy: 0.8283 - val_loss: 0.5515 - val_accuracy: 0.9007
# Epoch 464/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0160 - accuracy: 0.8338 - val_loss: 0.8866 - val_accuracy: 0.8423
# Epoch 465/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.0982 - accuracy: 0.8257 - val_loss: 0.5430 - val_accuracy: 0.8910
# Epoch 466/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0247 - accuracy: 0.8359 - val_loss: 0.9097 - val_accuracy: 0.8544
# Epoch 467/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.0848 - accuracy: 0.8243 - val_loss: 0.5027 - val_accuracy: 0.8855
# Epoch 468/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0116 - accuracy: 0.8318 - val_loss: 0.5346 - val_accuracy: 0.8843
# Epoch 469/500
# 205/205 [==============================] - 21s 101ms/step - loss: 0.9664 - accuracy: 0.8397 - val_loss: 0.5083 - val_accuracy: 0.8904
# Epoch 470/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.0766 - accuracy: 0.8309 - val_loss: 0.4762 - val_accuracy: 0.8904
# Epoch 471/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.1371 - accuracy: 0.8262 - val_loss: 0.5411 - val_accuracy: 0.8910
# Epoch 472/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0116 - accuracy: 0.8403 - val_loss: 0.5263 - val_accuracy: 0.8867
# Epoch 473/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0393 - accuracy: 0.8338 - val_loss: 0.6933 - val_accuracy: 0.8630
# Epoch 474/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.0474 - accuracy: 0.8324 - val_loss: 0.5024 - val_accuracy: 0.8879
# Epoch 475/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.0458 - accuracy: 0.8315 - val_loss: 0.4957 - val_accuracy: 0.8879
# Epoch 476/500
# 205/205 [==============================] - 21s 101ms/step - loss: 0.9383 - accuracy: 0.8367 - val_loss: 0.8580 - val_accuracy: 0.8581
# Epoch 477/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0583 - accuracy: 0.8336 - val_loss: 1.2074 - val_accuracy: 0.8155
# Epoch 478/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0705 - accuracy: 0.8228 - val_loss: 0.5240 - val_accuracy: 0.8812
# Epoch 479/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0179 - accuracy: 0.8361 - val_loss: 0.4477 - val_accuracy: 0.9007
# Epoch 480/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0246 - accuracy: 0.8274 - val_loss: 0.5329 - val_accuracy: 0.8672
# Epoch 481/500
# 205/205 [==============================] - 21s 101ms/step - loss: 0.9945 - accuracy: 0.8425 - val_loss: 0.5003 - val_accuracy: 0.8989
# Epoch 482/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0669 - accuracy: 0.8330 - val_loss: 0.7937 - val_accuracy: 0.8593
# Epoch 483/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0485 - accuracy: 0.8230 - val_loss: 0.4604 - val_accuracy: 0.8922
# Epoch 484/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0202 - accuracy: 0.8263 - val_loss: 0.4645 - val_accuracy: 0.8892
# Epoch 485/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0468 - accuracy: 0.8361 - val_loss: 0.9104 - val_accuracy: 0.8544
# Epoch 486/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.1004 - accuracy: 0.8240 - val_loss: 0.5142 - val_accuracy: 0.8916
# Epoch 487/500
# 205/205 [==============================] - 21s 102ms/step - loss: 0.9957 - accuracy: 0.8335 - val_loss: 0.6386 - val_accuracy: 0.8800
# Epoch 488/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.0377 - accuracy: 0.8274 - val_loss: 0.5403 - val_accuracy: 0.8758
# Epoch 489/500
# 205/205 [==============================] - 21s 101ms/step - loss: 0.9503 - accuracy: 0.8382 - val_loss: 0.7286 - val_accuracy: 0.8660
# Epoch 490/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.0341 - accuracy: 0.8347 - val_loss: 0.5235 - val_accuracy: 0.8965
# Epoch 491/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0947 - accuracy: 0.8301 - val_loss: 0.5004 - val_accuracy: 0.8873
# Epoch 492/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0561 - accuracy: 0.8347 - val_loss: 0.5491 - val_accuracy: 0.8819
# Epoch 493/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.0534 - accuracy: 0.8324 - val_loss: 0.5225 - val_accuracy: 0.8855
# Epoch 494/500
# 205/205 [==============================] - 21s 104ms/step - loss: 1.0719 - accuracy: 0.8274 - val_loss: 0.6630 - val_accuracy: 0.8733
# Epoch 495/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0340 - accuracy: 0.8355 - val_loss: 0.4778 - val_accuracy: 0.8904
# Epoch 496/500
# 205/205 [==============================] - 21s 103ms/step - loss: 1.1162 - accuracy: 0.8265 - val_loss: 0.4753 - val_accuracy: 0.8952
# Epoch 497/500
# 205/205 [==============================] - 21s 104ms/step - loss: 0.9856 - accuracy: 0.8342 - val_loss: 1.3762 - val_accuracy: 0.8124
# Epoch 498/500
# 205/205 [==============================] - 21s 101ms/step - loss: 1.0561 - accuracy: 0.8260 - val_loss: 0.5957 - val_accuracy: 0.8861
# Epoch 499/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0428 - accuracy: 0.8370 - val_loss: 0.5092 - val_accuracy: 0.8873
# Epoch 500/500
# 205/205 [==============================] - 21s 102ms/step - loss: 1.0751 - accuracy: 0.8370 - val_loss: 0.5757 - val_accuracy: 0.8855

# %%
model.save('DenseNet201_chest.h5')

# %%
model.save_weights('DenseNet201_chest.hdf5')

# %%
model = load_model('DenseNet201_chest.h5')

# %% [markdown]
# ### **Making Predicions**

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

# %% [markdown]
# ### Visulaizing First 10 predictions

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% COVID')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% NonCOVID')
  plt.imshow(X_test[index])
  plt.show()

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %% [markdown]
# ### Plot ROC Curve

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for our model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %% [markdown]
# ### Plot Confusion Matrix

# %%
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)

print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# Confusion Matrix without Normalization
# Confusion Matrix with Normalized Values

# %% [markdown]
# ### **Classification Report**

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88       811
#            1       0.84      0.95      0.89       831
#
#     accuracy                           0.89      1642
#    macro avg       0.89      0.88      0.88      1642
# weighted avg       0.89      0.89      0.88      1642

# %% [markdown]
# ### **Accuracy and Loss Plots**

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('DenseNet201_chest_accuracy.png')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('DenseNet201_chest_loss.png')
plt.show()
